# %% [markdown]
# # Import the pyplot module from matplotlib as plt and make sure
# # plots appear in the notebook using '%matplotlib inline'

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# # Create a simple plot using plt.plot()

# %%
plt.plot()
# Out:
# []

# %% [markdown]
# # Plot a single Python list

# %%
py_list=[1,2,3,4,5]
plt.plot(py_list)

# %%
py_list=[9,7,5,3,1]
plt.plot(py_list)

# %% [markdown]
# # Create two lists, one called X, one called y, each with 5 numbers in them

# %%
x=[5,6,7,8,9]
y=[25,36,49,64,81]

# %% [markdown]
# # Plot X & y (the lists you've created)

# %%
plt.plot(x,y)

# %%
x=np.random.randint(0,100,size=(5))
x
# Out:
# array([49, 38,  4,  5, 31])

# %%
y=np.random.randint(0,100,size=(5))
y
# Out:
# array([45, 11, 23, 34, 92])

# %%
plt.plot(x,y);

# %%
plt.scatter(x,y)

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.pie(y);

# %% [markdown]
# # Create a plot using plt.subplots()

# %%
fig,ax=plt.subplots()

# %% [markdown]
# # Create a plot using plt.subplots() and then add X & y on the axes

# %%
fig,ax=plt.subplots()
ax.plot(x,y);

# %%
# Import and get matplotlib ready
# %matplotlib inline
import matplotlib.pyplot as plt

# Prepare data (create two lists of 5 numbers, X & y)
x=[99,45,70,60,20]
y=[100,50,10,70,60]

# Setup figure and axes using plt.subplots()
fig,ax=plt.subplots()

# Add data (X, y) to axes
ax.plot(x,y)

# Customize plot by adding a title, xlabel and ylabel
ax.set(title='Exercise',xlabel='X-axis',ylabel='Y-axis')

## Save the plot to file using fig.savefig()
fig.savefig('exercise.png')

# %% [markdown]
# # Import NumPy as np

# %%
import numpy as np

# %% [markdown]
# # Create an array of 100 evenly spaced numbers between 0 and 100 using NumPy and save it to variable X

# %%
x=np.linspace(0,10,100)
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
#         6.56565657,  6.66666667,  6.76767677,  6.86868687,  6.96969697,
#         7.07070707,  7.17171717,  7.27272727,  7.37373737,  7.47474747,
#         7.57575758,  7.67676768,  7.77777778,  7.87878788,  7.97979798,
#         8.08080808,  8.18181818,  8.28282828,  8.38383838,  8.48484848,
#         8.58585859,  8.68686869,  8.78787879,  8.88888889,  8.98989899,
#         9.09090909,  9.19191919,  9.29292929,  9.39393939,  9.49494949,
#         9.5959596 ,  9.6969697 ,  9.7979798 ,  9.8989899 , 10.        ])

# %% [markdown]
# # Create a plot using plt.subplots() and plot X versus X^2 (X squared)

# %%
fig,ax=plt.subplots()
ax.plot(x,np.square(x))

# %% [markdown]
# # Create a scatter plot of X versus the exponential of X (np.exp(X))

# %%
fig,ax=plt.subplots()
ax.scatter(x,np.exp(x))

# %% [markdown]
# # Create a scatter plot of X versus np.sin(X)

# %%
fig,ax=plt.subplots()
ax.scatter(x,np.sin(x))

# %% [markdown]
# # Create a Python dictionary of 3 of your favourite foods with
# # The keys of the dictionary should be the food name and the values their price

# %%
food_dict={'Mango':10,'jackfruit':30,'jam':2}
food_dict
# Out:
# {'Mango': 10, 'jackfruit': 30, 'jam': 2}

# %% [markdown]
# # Create a bar graph where the x-axis is the keys of the dictionary
# # and the y-axis is the values of the dictionary

# %%
fig,ax=plt.subplots()
ax.bar(food_dict.keys(),food_dict.values())


# Add a title, xlabel and ylabel to the plot
ax.set(title='Fruit and price',xlabel='Fruits',ylabel='price')
# Out:
# [Text(0, 0.5, 'price'),
#  Text(0.5, 0, 'Fruits'),
#  Text(0.5, 1.0, 'Fruit and price')]

# %% [markdown]
# # Make the same plot as above, except this time make the bars go horizontal

# %%
fig,ax=plt.subplots()
ax.barh(list(food_dict.keys()),list(food_dict.values()))


# Add a title, xlabel and ylabel to the plot
ax.set(title='Fruit and price',xlabel='Fruits',ylabel='price');

),
#  <a list of 10 Patch objects>)

# %% [markdown]
# # Create an empty subplot with 2 rows and 2 columns (4 subplots total)

# %%
fig,((ax0,ax1),(ax2,ax3))=plt.subplots(nrows=2,ncols=2)

# %% [markdown]
# # Create the same plot as above with 2 rows and 2 columns and figsize of (10,5)

# %%
# Create the same plot as above with 2 rows and 2 columns and figsize of (10, 5)

fig,((ax0,ax1),(ax2,ax3))=plt.subplots(nrows=2,ncols=2,figsize=(10,5))

# Plot X versus X/2 on the top left axes
ax0.plot(x,x/2)

# Plot a scatter plot of 10 random numbers on each axis on the top right subplot
ax1.scatter(np.random.random(10),np.random.random(10))

# Plot a bar graph of the favourite food keys and values on the bottom left subplot
ax2.bar(food_dict.keys(),food_dict.values())

# Plot a histogram of 1000 random normally distributed numbers on the bottom right subplot
ax3.hist(np.random.randint(1000));

# %% [markdown]
# # Import pandas as pd

# %%
import pandas as pd

# %% [markdown]
# # Import the '../data/car-sales.csv' into a DataFame called car_sales and view

# %%
car_sales=pd.read_csv('car_sales.csv')
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors        Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# # Try to plot the 'Price' column using the plot() function

# %%
car_sales['Price'].plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-acc32476974d> in <module>
# ----> 1 car_sales['Price'].plot()
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     845                     data.columns = label_name
#     846
# --> 847         return plot_backend.plot(data, kind=kind, **kwargs)
#     848
#     849     __call__.__doc__ = __doc__
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in generate(self)
#     259     def generate(self):
#     260         self._args_adjust()
# --> 261         self._compute_plot_data()
#     262         self._setup_subplots()
#     263         self._make_plot()
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in _compute_plot_data(self)
#     408         # no non-numeric frames or series allowed
#     409         if is_empty:
# --> 410             raise TypeError("no numeric data to plot")
#     411
#     412         # GH25587: cast ExtensionArray of pandas (IntegerArray, etc.) to
#
# TypeError: no numeric data to plot

# %%
car_sales=pd.read_csv('car_sales.csv')
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors        Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales['Price']=car_sales['Price'].str.replace('[\$\,\.]','')
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors   Price
# 0  Toyota  White         150043      4   40000
# 1   Honda    Red          87899      4   50000
# 2  Toyota   Blue          32549      3   70000
# 3     BMW  Black          11179      5  220000
# 4  Nissan  White         213095      4   35000
# 5  Toyota  Green          99213      4   45000
# 6   Honda   Blue          45698      4   75000
# 7   Honda   Blue          54738      4   70000
# 8  Toyota  White          60000      4   62500
# 9  Nissan  White          31600      4   97000

# %% [markdown]
# # Add a column called 'Total Sales' to car_sales which cumulatively adds the 'Price' column

# %%
car_sales["Price"] = car_sales["Price"].str[:-2]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors Price
# 0  Toyota  White         150043      4   400
# 1   Honda    Red          87899      4   500
# 2  Toyota   Blue          32549      3   700
# 3     BMW  Black          11179      5  2200
# 4  Nissan  White         213095      4   350
# 5  Toyota  Green          99213      4   450
# 6   Honda   Blue          45698      4   750
# 7   Honda   Blue          54738      4   700
# 8  Toyota  White          60000      4   625
# 9  Nissan  White          31600      4   970

# %%
car_sales['total sales']=car_sales['Price'].astype(int).cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors Price  total sales
# 0  Toyota  White         150043      4   400          400
# 1   Honda    Red          87899      4   500          900
# 2  Toyota   Blue          32549      3   700         1600
# 3     BMW  Black          11179      5  2200         3800
# 4  Nissan  White         213095      4   350         4150
# 5  Toyota  Green          99213      4   450         4600
# 6   Honda   Blue          45698      4   750         5350
# 7   Honda   Blue          54738      4   700         6050
# 8  Toyota  White          60000      4   625         6675
# 9  Nissan  White          31600      4   970         7645

# %% [markdown]
# # Add a column called 'Sale Date' which lists a series of successive dates starting from today (your today)

# %%
car_sales['sale date']=pd.date_range('1/1/2020',periods=len(car_sales))

# View the car_sales DataFrame
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors Price  total sales  sale date
# 0  Toyota  White         150043      4   400          400 2020-01-01
# 1   Honda    Red          87899      4   500          900 2020-01-02
# 2  Toyota   Blue          32549      3   700         1600 2020-01-03
# 3     BMW  Black          11179      5  2200         3800 2020-01-04
# 4  Nissan  White         213095      4   350         4150 2020-01-05
# 5  Toyota  Green          99213      4   450         4600 2020-01-06
# 6   Honda   Blue          45698      4   750         5350 2020-01-07
# 7   Honda   Blue          54738      4   700         6050 2020-01-08
# 8  Toyota  White          60000      4   625         6675 2020-01-09
# 9  Nissan  White          31600      4   970         7645 2020-01-10

# %% [markdown]
# # Use the plot() function to plot the 'Sale Date' column versus the 'Total Sales' column

# %%
fig,ax=plt.subplots(figsize=(10,10))
ax.plot(car_sales['sale date'],car_sales['total sales']);

# %% [markdown]
# # Convert the 'Price' column to the integers

# %%
type(car_sales['Price'])
# Out:
# pandas.core.series.Series

# %%
car_sales['Price']=car_sales['Price'].astype(int)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  total sales  sale date
# 0  Toyota  White         150043      4    400          400 2020-01-01
# 1   Honda    Red          87899      4    500          900 2020-01-02
# 2  Toyota   Blue          32549      3    700         1600 2020-01-03
# 3     BMW  Black          11179      5   2200         3800 2020-01-04
# 4  Nissan  White         213095      4    350         4150 2020-01-05
# 5  Toyota  Green          99213      4    450         4600 2020-01-06
# 6   Honda   Blue          45698      4    750         5350 2020-01-07
# 7   Honda   Blue          54738      4    700         6050 2020-01-08
# 8  Toyota  White          60000      4    625         6675 2020-01-09
# 9  Nissan  White          31600      4    970         7645 2020-01-10

# %%
type(car_sales['Price'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# # Create a scatter plot of the 'Odometer (KM)' and 'Price' column usingthe plot() function

# %%
fig,ax=plt.subplots(figsize=(10,6))
ax.scatter(car_sales['Price'],car_sales['Odometer (KM)']);

# %% [markdown]
# # Create a NumPy array of random numbers of size (10, 4) and save it to X

# %%
x=np.random.random((10,4))
x
# Out:
# array([[0.88104201, 0.13448328, 0.33484719, 0.84418336],
#        [0.16584796, 0.40448135, 0.08674563, 0.31917663],
#        [0.76095168, 0.18471427, 0.4353457 , 0.19605725],
#        [0.77854175, 0.60406425, 0.014487  , 0.93689005],
#        [0.68016018, 0.72943006, 0.8188336 , 0.13954585],
#        [0.45169545, 0.96048104, 0.17056491, 0.1869611 ],
#        [0.31404655, 0.00903342, 0.5184916 , 0.9429158 ],
#        [0.39308012, 0.62079444, 0.7643262 , 0.0824576 ],
#        [0.43761436, 0.30064917, 0.30493276, 0.76666117],
#        [0.40639069, 0.67657267, 0.19481045, 0.73903304]])

# %% [markdown]
# # Turn the NumPy array X into a DataFrame with columns called ['a','b', 'c', 'd']

# %%
data_x=pd.DataFrame(x,columns=['a','b','c','d'])
data_x
# Out:
#           a         b         c         d
# 0  0.881042  0.134483  0.334847  0.844183
# 1  0.165848  0.404481  0.086746  0.319177
# 2  0.760952  0.184714  0.435346  0.196057
# 3  0.778542  0.604064  0.014487  0.936890
# 4  0.680160  0.729430  0.818834  0.139546
# 5  0.451695  0.960481  0.170565  0.186961
# 6  0.314047  0.009033  0.518492  0.942916
# 7  0.393080  0.620794  0.764326  0.082458
# 8  0.437614  0.300649  0.304933  0.766661
# 9  0.406391  0.676573  0.194810  0.739033

# %% [markdown]
# # Create a bar graph of the DataFrame

# %%
data_x.plot(kind='bar',figsize=(10,10))

# %% [markdown]
# # Create a bar graph of the 'Make' and 'Odometer (KM)' columns in the car_sales DataFrame

# %%
fig,ax=plt.subplots()
ax.bar(car_sales['Make'],car_sales['Odometer (KM)'])
# Out:
# <BarContainer object of 10 artists>

# %%
car_sales.plot(x='Make',y='Odometer (KM)',kind='bar')

# %% [markdown]
# # Create a histogram of the 'Odometer (KM)' column

# %%
fig,ax=plt.subplots()
ax.hist(car_sales['Odometer (KM)'])
# Out:
# (array([1., 3., 2., 1., 1., 0., 1., 0., 0., 1.]),
#  array([ 11179. ,  31370.6,  51562.2,  71753.8,  91945.4, 112137. ,
#         132328.6, 152520.2, 172711.8, 192903.4, 213095. ]),
#  <a list of 10 Patch objects>)

# %%
car_sales['Odometer (KM)'].plot(kind='hist')

# %% [markdown]
# # Create a histogram of the 'Price' column with 20 bins

# %%
car_sales['Price'].hist(bins=20)

# %% [markdown]
# # Import "../data/heart-disease.csv" and save it to the variable "heart_disease"

# %%
heart_disease =pd.read_csv('heart-disease.csv')
heart_disease
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [303 rows x 14 columns]

# %% [markdown]
# # View the first 10 rows of the heart_disease DataFrame

# %%
heart_disease.head(10)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
# 7   44    1   1       120   263    0        1      173      0      0.0      2
# 8   52    1   2       172   199    1        1      162      0      0.5      2
# 9   57    1   2       150   168    0        1      174      0      1.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1
# 7   0     3       1
# 8   0     3       1
# 9   0     2       1

# %% [markdown]
# # Create a histogram of the "age" column with 50 bins

# %%
fig,ax=plt.subplots()
ax.hist(heart_disease['age'],bins=50);

# %%
heart_disease['age'].hist(bins=50)

# %%
heart_disease['age'].plot.hist(bins=50)

# %% [markdown]
# # Call plot.hist() on the heart_disease DataFrame and toggle the
# # "subplots" parameter to True

# %%
heart_disease.plot.hist(subplots=True);

# %% [markdown]
# # Call the same line of code from above except change the "figsize" parameter
# # to be (10, 30)

# %%
heart_disease.plot.hist(subplots=True,figsize=(10,30));

# %%
df_over50=heart_disease[heart_disease['age']>50]
df_over50
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 297   59    1   0       164   176    1        0       90      0      1.0
# 298   57    0   0       140   241    0        1      123      1      0.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 3        2   0     2       1
# 4        2   0     2       1
# 5        1   0     1       1
# 6        1   0     2       1
# ..     ...  ..   ...     ...
# 297      1   2     1       0
# 298      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [208 rows x 14 columns]

# %%
fig,ax=plt.subplots(figsize=(10,6))
s=ax.scatter(df_over50['age'],df_over50['chol'],c=df_over50['target'])
ax.set(title='Heart disease and cholesterol levels',xlabel='age',ylabel='cholesterol')
ax.legend(*s.legend_elements(),title='target')
ax.axhline(df_over50['chol'].mean(),linestyle='--');

# %% [markdown]
# # Check what styles are available under plt

# %%
plt.style.available
# Out:
# ['bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn',
#  'Solarize_Light2',
#  'tableau-colorblind10',
#  '_classic_test']

# %% [markdown]
# # Change the style to use "seaborn-whitegrid"

# %%
plt.style.use('seaborn-whitegrid')

# %%
plt.plot([1,2,3,4],[5,6,7,8])

# %%
fig,ax=plt.subplots(figsize=(10,6))
s=ax.scatter(df_over50['age'],df_over50['chol'],c=df_over50['target'],cmap='winter')
ax.set(title='Heart disease and cholesterol levels',xlabel='age',ylabel='cholesterol')
ax.legend(*s.legend_elements(),title='target')
ax.axhline(df_over50['chol'].mean(),linestyle='--',color='red');
